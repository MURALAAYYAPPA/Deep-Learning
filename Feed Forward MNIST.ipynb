# %% [markdown]
# <a href="https://colab.research.google.com/github/MURALAAYYAPPA/Deep-Learning/blob/main/Feed%20Forward%20MNIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt

#import the dataset
(x_train,y_train),(x_test,y_test)=mnist.load_data()

#Normalize the pixel values -varying btw 0 - 1
x_train=x_train.reshape(-1,28*28).astype("float32")/255
x_test=x_test.reshape(-1,28*28).astype("float32")/255

#model the Network
model=keras.models.Sequential([
    layers.Dense(128,activation='relu',input_shape=(784,)),
    layers.Dense(64,activation='relu'),
    layers.Dense(10,activation ='softmax')])

#compile the model
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy'])

#Evaluate the mdel
history=model.fit(x_train,y_train,epochs=5,batch_size=128,validation_split=0.1)
test_loss,test_acc=model.evaluate(x_test,y_test)
print(f"Test accuracy :{test_acc:.4f}")
print(f"Test loss :{test_loss:.4f}")


#plot the Graph
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy vs Epochs')
plt.savefig('Accuracy-MNIST.tiff')
plt.show()
# Out:
# Epoch 1/5
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8157 - loss: 0.6494 - val_accuracy: 0.9562 - val_loss: 0.1489
# Epoch 2/5
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9564 - loss: 0.1537 - val_accuracy: 0.9625 - val_loss: 0.1252
# Epoch 3/5
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9672 - loss: 0.1077 - val_accuracy: 0.9743 - val_loss: 0.0921
# Epoch 4/5
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9762 - loss: 0.0809 - val_accuracy: 0.9760 - val_loss: 0.0859
# Epoch 5/5
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9823 - loss: 0.0602 - val_accuracy: 0.9767 - val_loss: 0.0837
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9705 - loss: 0.0989
# Test accuracy :0.9735
# Test loss :0.0908
