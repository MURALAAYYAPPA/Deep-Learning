# %% [markdown]
# <a href="https://colab.research.google.com/github/MURALAAYYAPPA/Deep-Learning/blob/main/PCNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.applications.vgg16 import VGG16,preprocess_input,decode_predictions
from tensorflow.keras.preprocessing import image
import numpy as np

# %%
model=VGG16(weights='imagenet')
my_image_path='/content/img.jpg'

# %%
def classify_image(img_path):
    try:
        img=image.load_img(img_path,target_size=(224,224))
        x=image.img_to_array(img)
        x=np.expand_dims(x,axis=0)
        x=preprocess_input(x)
        preds=model.predict(x)
        print('Result:')
        for x in decode_predictions(preds,top=3)[0]:
            print(f"{x[1]}:{x[2]*100:.2f}%")
    except Exception as e:
        print(f"Error:could not find or load the image,check the path!\n Details:{e}")
        # The original code had classify_image(my_image_path) here which would cause infinite recursion if the image is not found.
        # Removing it as it's likely not the intended behavior for an error handler.

# %%
classify_image(my_image_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Result:
# ...
# 35363/35363 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# racer:54.17%
# sports_car:20.65%
# cab:4.73%

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.applications.vgg16 import VGG16,preprocess_input,decode_predictions
from tensorflow.keras.preprocessing import image
import numpy as np
model=VGG16(weights='imagenet')
my_image_path='/content/fruits.jpg'
def classify_image(img_path):
    try:
        img=image.load_img(img_path,target_size=(224,224))
        x=image.img_to_array(img)
        x=np.expand_dims(x,axis=0)
        x=preprocess_input(x)
        preds=model.predict(x)
        print('Result:')
        for x in decode_predictions(preds,top=3)[0]:
            print(f"{x[1]}:{x[2]*100:.2f}%")
    except Exception as e:
        print(f"Error:could not find or load the image,check the path!\n Details:{e}")
classify_image(my_image_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 821ms/step
# Result:
# hamper:13.40%
# pineapple:12.52%
# lemon:8.16%
